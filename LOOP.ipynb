# %%
#Nested for loop

# %%
l2 = [1,2,3]
l3 = ["goole", "meta", "fujitsu"]

for x in l2:
    for y in l3:
        print(x,y)
# Out:
# 1 goole
# 1 meta
# 1 fujitsu
# 2 goole
# 2 meta
# 2 fujitsu
# 3 goole
# 3 meta
# 3 fujitsu

# %%
num = int(input("Enter any number:"))
fact = 1
for i in range(1, num+1):
    fact =fact* i
print("factorial of anumber is",fact)
# Out:
# Enter any number: 3
# factorial of anumber is 6

# %%
n = int(input("Enter any number:"))
f = 1
while n >= 1:
    f = f * n
    n = n-1
print("Factorial is",f)
# Out:
# Enter any number: 5
# Factorial is 120

# %%
num = int(input("Enter any number:"))
for i in range(2,num):
    if (num % i) == 0:
        print(num, "is not a prime number")
        break
else:
    print(num, "is a prime number")
# Out:
# Enter any number: 13
# 13 is a prime number

# %%
num = int(input("Enter any number:"))
rev=0
x=num
while(num>0):
    rev=(rev*10)+num%10
    num=num//10
if(x==rev):
    print("given number is palindrome")
else:
    print("given number is not palindrome")
# Out:
# Enter any number: 121
# given number is palindrome

# %%
num = int(input("Enter any number:"))
rev=0
x=num
while(num>0):
    rev=(rev*10)+num%10
    num=num//10
if(x==rev):
    print("given number is palindrome")
else:
    print("given number is not palindrome")
# Out:
# Enter any number: 324
# given number is not palindrome

# %%
n= int(input("Enter any number:"))
x=n
sum=0
while(n>0):
    sum=sum+(n%10)*(n%10)*(n%10)
    n=n//10
if x==sum:
    print("Number is armstrong")
else:
    print("Number is not armstrong")
# Out:
# Enter any number: 153
# Number is armstrong

# %%
num = int(input("Enter any number:"))
rev=0
x=num
while(num>0):
    rev=(rev*10)+num%10
    num=num//10
if(x==rev):
    print("given number is palindrome")
else:
    print("given number is not palindrome")
# Out:
# Enter any number: 134
# given number is not palindrome

# %%
n= int(input("Enter any number:"))
x=n
sum=0
while(n>0):
    sum=sum+(n%10)*(n%10)*(n%10)
    n=n//10
if x==sum:
    print("Number is armstrong")
else:
    print("Number is not armstrong")
# Out:
# Enter any number: 134
# Number is not armstrong

# %%
n= int(input("Enter the limit number:"))
x=0
y=1
z=0
while(z<=n):
    print(z)
    x=y
    y=z
    z=x+y
# Out:
# Enter the limit number: 20
# 0
# 1
# 1
# 2
# 3
# 5
# 8
# 13

# %%
n= int(input("Enter the limit number:"))
x=0
y=1
z=0
while(z<=n):
    print(z)
    x=y
    y=z
    z=x+y
# Out:
# Enter the limit number: 10
# 0
# 1
# 1
# 2
# 3
# 5
# 8

# %%
num=int(input("Enter number of rows:"))
for i in range(1,num+1):
    for j in range(1,i+1):
        print("*",end=" ")
    print()
# Out:
# Enter number of rows: 10
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * * * *
# * * * * * * *
# * * * * * * * *
# * * * * * * * * *
# * * * * * * * * * *

# %%
num=int(input("Enter number of rows:"))
for i in range(1,num+1):
    for j in range(1,i+1):
        print("*",end=" ")
    print()
# Out:
# Enter number of rows: 5
# *
# * *
# * * *
# * * * *
# * * * * *
