# %%
#wap to swap two number using third variable.
a=10
b=20
temp=a
a=b
b=temp
print("value of a:",a)
print("value of b:",b)
# Out:
# value of a: 20
# value of b: 10

# %%
#wap to swap two number using without third variable.
a=15
b=25
a,b=b,a
print("value of a:",a)
print("value of a:",b)
# Out:
# value of a: 25
# value of a: 15
